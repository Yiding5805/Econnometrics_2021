# %% [markdown]
# <a href="https://colab.research.google.com/github/Yiding5805/Econnometrics_2021/blob/main/M6_Active.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Timeseries variables

# %% [markdown]
# [Data Metrics](https://github.com/coinmetrics-io/data/blob/master/csv/metrics.csv)

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### import the data for Ethereum

# %%
df=pd.read_csv("https://raw.githubusercontent.com/coinmetrics-io/data/master/csv/eth.csv")
df['time']=pd.to_datetime(df['time'])
df.head()
# Out:
#         time  AdrActCnt  ...  VtyDayRet180d  VtyDayRet30d
# 0 2015-07-30     9206.0  ...            NaN           NaN
# 1 2015-07-31      424.0  ...            NaN           NaN
# 2 2015-08-01      413.0  ...            NaN           NaN
# 3 2015-08-02      432.0  ...            NaN           NaN
# 4 2015-08-03      444.0  ...            NaN           NaN
#
# [5 rows x 139 columns]

# %%
import plotly.express as px
import plotly.offline as py     
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# %%
trace0 = go.Scatter(x = df["time"], y = df["TxTfrValAdjUSD"], hoverinfo='x+y', mode='lines',  name = 'Transactions, transfers, value, adjusted, USD')
trace1 = go.Scatter(x = df["time"], y = df['AdrActCnt'], hoverinfo='x+y', mode='lines',  name = 'AdrActCnt	Addresses, active, count')

layout = go.Layout(title="Address Active Count and Transaction Value ", xaxis = dict(title="date"), yaxis = dict(title ="USD") ) 
data = [trace0, trace1]


fig1 = go.Figure(layout = layout, data = data) 
fig1.update_yaxes(type="log")
fig1.update_xaxes(
    rangeslider_visible=True,
    rangeselector=dict(
        buttons=list([
            dict(step="all"),
            dict(count=1, label="1m", step="month", stepmode="backward"),
            dict(count=3, label="3m", step="month", stepmode="backward"),
            dict(count=3, label="6m", step="month", stepmode="backward"),
            dict(count=1, label="1y", step="year", stepmode="backward"),
            dict(count=1, label="YTD", step="year", stepmode="todate"),
          
        ])))
py.iplot(fig1)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="a3507019-3579-4ab3-9829-1396474871be" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("a3507019-3579-4ab3-9829-1396474871be")) {
#                     Plotly.newPlot(
#                         'a3507019-3579-4ab3-9829-1396474871be',
#                         [{"hoverinfo": "x+y", "mode": "lines", "name": "Transactions, transfers, value, adjusted, USD", "type": "scatter", "x": ["2015-07-30T00:00:00", "2015-07-31T00:00:00", "2015-08-01T00:00:00", "2015-08-02T00:00:00", "2015-08-03T00:00:00", "2015-08-04T00:00:00", "2015-08-05T00:00:00", "2015-08-06T00:00:00", "2015-08-07T00:00:00", "2015-08-08T00:00:00", "2015-08-09T00:00:00", "2015-08-10T00:00:00", "2015-08-11T00:00:00", "2015-08-12T00:00:00", "2015-08-13T00:00:00", "2015-08-14T00:00:00", "2015-08-15T00:00:00", "2015-08-16T00:00:00", "2015-08-17T00:00:00", "2015-08-18T00:00:00", "2015-08-19T00:00:00", "2015-08-20T00:00:00", "2015-08-21T00:00:00", "2015-08-22T00:00:00", "2015-08-23T00:00:00", "2015-08-24T00:00:00", "2015-08-25T00:00:00", "2015-08-26T00:00:00", "2015-08-27T00:00:00", "2015-08-28T00:00:00", "2015-08-29T00:00:00", "2015-08-30T00:00:00", "2015-08-31T00:00:00", "2015-09-01T00:00:00", "2015-09-02T00:00:00", "2015-09-03T00:00:00", "2015-09-04T00:00:00", "2015-09-05T00:00:00", "2015-09-06T00:00:00", "2015-09-07T00:00:00", "2015-09-08T00:00:00", "2015-09-09T00:00:00", "2015-09-10T00:00:00", "2015-09-11T00:00:00", "2015-09-12T00:00:00", "2015-09-13T00:00:00
016-01-04T00:00:00", "2016-01-05T00:00:00", "2016-01-06T00:00:00", "2016-01-07T00:00:00", "2016-01-08T00:00:00", "2016-01-09T00:00:00", "2016-01-10T00:00:00", "2016-01-11T00:00:00", "2016-01-12T00:00:00", "2016-01-13T00 ...

# %% [markdown]
# ### Calculate lag variables

# %% [markdown]
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.shift.html

# %%
df['AdrActCnt_Minus_1']=df['AdrActCnt'].shift(1)
df[['AdrActCnt','AdrActCnt_Minus_1']].tail()
# Out:
#       AdrActCnt  AdrActCnt_Minus_1
# 2149   585530.0           589164.0
# 2150   576902.0           585530.0
# 2151   578685.0           576902.0
# 2152   641786.0           578685.0
# 2153   643760.0           641786.0

# %% [markdown]
# ###Calculate differences

# %% [markdown]
# https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.diff.html

# %%
df['AdrActCnt_Diff_1']=df['AdrActCnt'].diff(1)
df[['AdrActCnt','AdrActCnt_Diff_1']].tail()
# Out:
#       AdrActCnt  AdrActCnt_Diff_1
# 2149   585530.0           -3634.0
# 2150   576902.0           -8628.0
# 2151   578685.0            1783.0
# 2152   641786.0           63101.0
# 2153   643760.0            1974.0

# %% [markdown]
# ### Calculate Growth Rate and Approximate Growth Rate

# %% [markdown]
# https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.pct_change.html

# %%
df['AdrActCnt_Growth_1']=df['AdrActCnt'].pct_change(1)
df['AdrActCnt_Growth_Aprx_1']=np.log(df['AdrActCnt']).diff(1)
df[['AdrActCnt','AdrActCnt_Growth_1','AdrActCnt_Growth_Aprx_1']].tail()
# Out:
#       AdrActCnt  AdrActCnt_Growth_1  AdrActCnt_Growth_Aprx_1
# 2149   585530.0           -0.006168                -0.006187
# 2150   576902.0           -0.014735                -0.014845
# 2151   578685.0            0.003091                 0.003086
# 2152   641786.0            0.109042                 0.103497
# 2153   643760.0            0.003076                 0.003071

# %%
trace0 = go.Scatter(x = df["time"], y = df["AdrActCnt_Growth_1"], hoverinfo='x+y', mode='lines',  name = 'The Growth Rate of Price, Percentage')
trace1 = go.Scatter(x = df["time"], y = df['AdrActCnt_Growth_Aprx_1'], hoverinfo='x+y', mode='lines',  name = 'The Growth Rate of Price Approximation, Percentage')

layout = go.Layout(title="Time series variables", xaxis = dict(title="date"), yaxis = dict(title ="Percentage") ) 
data = [trace0, trace1]


fig1 = go.Figure(layout = layout, data = data) 
fig1.update_xaxes(
    rangeslider_visible=True,
    rangeselector=dict(
        buttons=list([
            dict(step="all"),
            dict(count=1, label="1m", step="month", stepmode="backward"),
            dict(count=3, label="3m", step="month", stepmode="backward"),
            dict(count=3, label="6m", step="month", stepmode="backward"),
            dict(count=1, label="1y", step="year", stepmode="backward"),
            dict(count=1, label="YTD", step="year", stepmode="todate"),
          
        ])))
py.iplot(fig1)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="287fce89-57b5-428a-8bbc-99ddd65ec799" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("287fce89-57b5-428a-8bbc-99ddd65ec799")) {
#                     Plotly.newPlot(
#                         '287fce89-57b5-428a-8bbc-99ddd65ec799',
#                         [{"hoverinfo": "x+y", "mode": "lines", "name": "The Growth Rate of Price, Percentage", "type": "scatter", "x": ["2015-07-30T00:00:00", "2015-07-31T00:00:00", "2015-08-01T00:00:00", "2015-08-02T00:00:00", "2015-08-03T00:00:00", "2015-08-04T00:00:00", "2015-08-05T00:00:00", "2015-08-06T00:00:00", "2015-08-07T00:00:00", "2015-08-08T00:00:00", "2015-08-09T00:00:00", "2015-08-10T00:00:00", "2015-08-11T00:00:00", "2015-08-12T00:00:00", "2015-08-13T00:00:00", "2015-08-14T00:00:00", "2015-08-15T00:00:
015-12-01T00:00:00", "2015-12-02T00:00:00", "2015-12-03T00:00:00", "2015-12-04T00:00:00", "2015-12-05T00:00:00", "2015-12-06T00:00:00", "2015-12-07T00:00:00", "2015-12-08T00:00:00", "2015-12-09T00:00:00", "2015-12-10T00:00:00", "2015-12-11T00:00:00", "2015-12-12T00:00:00", "2015-12-13T00:00:00", "2015-12-14T00:00:00", "2015-12-15T00:00:00", "2015-12-16T00:00:00", "2015-12-17T00:00:00", "2015-12-18T00:00:00", "2015-12-19T00:00:00", "2015-12-20T00:00:00", "2015-12-21T00:00:00", "2015-12-22T00:00:00", "2015-12-23T00:00:00", "2015-12-24T00:00:00", "2015-12-25T00:00:00", "2015-12-26T00:00:00", "2015-12-27T00:00:00", "2015-12-28T00:00:00", "2015-12-29T00:00:00", "2015-12-30T00:00:00", "2015-12-31T00:00:00", "2016-01-01T00:00:00", "2016-01-02T00:00:00", "2016-01-03T00:00:00", "2016-01-04T00:00:00", "2016-01-05T00:00:00", "2016-01-06T00:00:00", "2016-01-07T00:00:00", "2016-01-08T00:00:00", "2016-01-09T00:00:00", "2016-01-10T00:00:00", "2016-01-11T00:00:00", "2016-01-12T00:00:00", "2016-01-13T00:00:00",  ...

# %% [markdown]
# ### lag plot

# %%
s=df['AdrActCnt']
pd.plotting.lag_plot(s, lag=1)

# %%
s=df['AdrActCnt']
pd.plotting.lag_plot(s, lag=2)

# %%
s=df['AdrActCnt']
pd.plotting.lag_plot(s, lag=3)

# %% [markdown]
# ### auto-correlation plot

# %% [markdown]
# https://pandas.pydata.org/docs/reference/api/pandas.plotting.autocorrelation_plot.html

# %%
s=df['AdrActCnt'].dropna()
pd.plotting.autocorrelation_plot(s)

# %% [markdown]
# ###calculate auto-correlation coefficient

# %%
s=df['AdrActCnt'].dropna()
s.autocorr(lag=1)
# Out:
# 0.8365285908161775

# %%
s=df['AdrActCnt'].dropna()
s.autocorr(lag=2)
# Out:
# 0.6117153537118006

# %%
s=df['AdrActCnt'].dropna()
s.autocorr(lag=3)
# Out:
# 0.5129640927376051

# %% [markdown]
# #Auto Regressions

# %% [markdown]
# ### AR(1) Manually

# %% [markdown]
# https://www.statsmodels.org/stable/regression.html

# %%
import statsmodels.api as sm

# %%
# define the dependent and independent variables
df=df.dropna()
X=df["AdrActCnt_Minus_1"]
y=df['AdrActCnt']

# %%
# add a constant to the dependent variables
X= sm.add_constant(X)
X.head()
# Out:
#      const  AdrActCnt_Minus_1
# 374    1.0            19499.0
# 375    1.0            20085.0
# 376    1.0            20439.0
# 377    1.0            22799.0
# 378    1.0            21183.0

# %%
# conduct regression
model = sm.OLS(y, X).fit()

# %%
# print model summary
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              AdrActCnt   R-squared:                       0.652
# Model:                            OLS   Adj. R-squared:                  0.652
# Method:                 Least Squares   F-statistic:                     3330.
# Date:                Wed, 23 Jun 2021   Prob (F-statistic):               0.00
# Time:                        08:10:29   Log-Likelihood:                -24166.
# No. Observations:                1780   AIC:                         4.834e+04
# Df Residuals:                    1778   BIC:                         4.835e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const              6.505e+04   6519.591      9.977      0.000    5.23e+04    7.78e+04
# AdrActCnt_Minus_1     0.8074      0.014     57.703      0.000       0.780       0.835
# ==============================================================================
# Omnibus:                     3053.661   Durbin-Watson:                   1.494
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         12245062.133
# Skew:                          10.759   Prob(JB):                         0.00
# Kurtosis:                     408.757   Cond. No.                     6.72e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 6.72e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# ### AR(P) statsmodel

# %%
pip install statsmodels --upgrade
# Out:
# Requirement already up-to-date: statsmodels in /usr/local/lib/python3.7/dist-packages (0.12.2)
# Requirement already satisfied, skipping upgrade: numpy>=1.15 in /usr/local/lib/python3.7/dist-packages (from statsmodels) (1.19.5)
# Requirement already satisfied, skipping upgrade: scipy>=1.1 in /usr/local/lib/python3.7/dist-packages (from statsmodels) (1.4.1)
# Requirement already satisfied, skipping upgrade: pandas>=0.21 in /usr/local/lib/python3.7/dist-packages (from statsmodels) (1.1.5)
# Requirement already satisfied, skipping upgrade: patsy>=0.5 in /usr/local/lib/python3.7/dist-packages (from statsmodels) (0.5.1)
# Requirement already satisfied, skipping upgrade: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.21->statsmodels) (2018.9)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.21->statsmodels) (2.8.1)
# Requirement already satisfied, skipping upgrade: six in /usr/local/lib/python3.7/dist-packages (from patsy>=0.5->statsmodels) (1.15.0)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import pandas_datareader as pdr
import seaborn as sns
from statsmodels.tsa.ar_model import AutoReg, ar_select_order
from statsmodels.tsa.api import acf, pacf, graphics

# %%
#This cell sets the plotting style, registers pandas date converters for matplotlib, and sets the default figure size.
sns.set_style('darkgrid')
pd.plotting.register_matplotlib_converters()
# Default figure size
sns.mpl.rc('figure',figsize=(16, 6))

# %% [markdown]
# AR (3)

# %%
s=df['AdrActCnt'].dropna()
mod = AutoReg(s, 3, old_names=False)
res = mod.fit()
print(res.summary())
# Out:
#                             AutoReg Model Results
# ==============================================================================
# Dep. Variable:              AdrActCnt   No. Observations:                 1780
# Model:                     AutoReg(3)   Log Likelihood              -23931.021
# Method:               Conditional MLE   S.D. of innovations         170783.647
# Date:                Wed, 23 Jun 2021   AIC                             24.102
# Time:                        08:10:32   BIC                             24.117
# Sample:                             3   HQIC                            24.108
#                                  1780
# ================================================================================
#                    coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const         5.732e+04   6302.230      9.096      0.000     4.5e+04    6.97e+04
# AdrActCnt.L1     1.1644      0.022     52.036      0.000       1.121       1.208
# AdrActCnt.L2    -0.6657      0.032    -20.899      0.000      -0.728      -0.603
# AdrActCnt.L3     0.3318      0.022     14.830      0.000       0.288       0.376
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            1.1877           -0.0000j            1.1877           -0.0000
# AR.2            0.4091           -1.5394j            1.5929           -0.2087
# AR.3            0.4091           +1.5394j            1.5929            0.2087
# -----------------------------------------------------------------------------
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/base/tsa_model.py:579: ValueWarning:
#
# An unsupported index was provided and will be ignored when e.g. forecasting.

# %%
res = mod.fit(cov_type="HC0")
print(res.summary())
# Out:
#                             AutoReg Model Results
# ==============================================================================
# Dep. Variable:              AdrActCnt   No. Observations:                 1780
# Model:                     AutoReg(3)   Log Likelihood              -23931.021
# Method:               Conditional MLE   S.D. of innovations         170783.647
# Date:                Wed, 23 Jun 2021   AIC                             24.102
# Time:                        08:10:32   BIC                             24.117
# Sample:                             3   HQIC                            24.108
#                                  1780
# ================================================================================
#                    coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const         5.732e+04   2.56e+04      2.240      0.025    7171.057    1.07e+05
# AdrActCnt.L1     1.1644      0.235      4.960      0.000       0.704       1.625
# AdrActCnt.L2    -0.6657      0.250     -2.662      0.008      -1.156      -0.175
# AdrActCnt.L3     0.3318      0.112      2.975      0.003       0.113       0.550
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            1.1877           -0.0000j            1.1877           -0.0000
# AR.2            0.4091           -1.5394j            1.5929           -0.2087
# AR.3            0.4091           +1.5394j            1.5929            0.2087
# -----------------------------------------------------------------------------

# %%
fig = res.plot_predict(720, 840)
# Out:
# No handles with labels found to put in legend.

# %%
fig = plt.figure(figsize=(16,9))
fig = res.plot_diagnostics(fig=fig, lags=30)

# %% [markdown]
# ### how to choice the number of Lag: BIC and AIC criteria

# %%
s=df['AdrActCnt'].pct_change(1).dropna()
sel = ar_select_order(s, 13,'bic', old_names=False)
sel.ar_lags
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/base/tsa_model.py:579: ValueWarning:
#
# An unsupported index was provided and will be ignored when e.g. forecasting.
#
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/base/tsa_model.py:579: ValueWarning:
#
# An unsupported index was provided and will be ignored when e.g. forecasting.
# array([1])

# %%
sel = ar_select_order(s, 13, 'bic', old_names=False)
sel.ar_lags
res = sel.model.fit()
print(res.summary())
# Out:
#                             AutoReg Model Results
# ==============================================================================
# Dep. Variable:              AdrActCnt   No. Observations:                 1779
# Model:                     AutoReg(1)   Log Likelihood               -2697.131
# Method:               Conditional MLE   S.D. of innovations              1.103
# Date:                Wed, 23 Jun 2021   AIC                              0.199
# Time:                        08:14:14   BIC                              0.209
# Sample:                             1   HQIC                             0.203
#                                  1779
# ================================================================================
#                    coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const            0.0397      0.026      1.517      0.129      -0.012       0.091
# AdrActCnt.L1     0.1169      0.024      4.962      0.000       0.071       0.163
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            8.5568           +0.0000j            8.5568            0.0000
# -----------------------------------------------------------------------------
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/base/tsa_model.py:579: ValueWarning:
#
# An unsupported index was provided and will be ignored when e.g. forecasting.
#
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/base/tsa_model.py:579: ValueWarning:
#
# An unsupported index was provided and will be ignored when e.g. forecasting.

# %%
fig = plt.figure(figsize=(16,9))
fig = res.plot_diagnostics(fig=fig, lags=30)

# %%
s=df['AdrActCnt'].pct_change(1).dropna()
sel = ar_select_order(s, 13,'aic', old_names=False)
sel.ar_lags
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/base/tsa_model.py:579: ValueWarning:
#
# An unsupported index was provided and will be ignored when e.g. forecasting.
#
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/base/tsa_model.py:579: ValueWarning:
#
# An unsupported index was provided and will be ignored when e.g. forecasting.
# array([1])

# %%
s=df['AdrActCnt'].pct_change(1).dropna()
sel = ar_select_order(s, 13, 'aic', old_names=False)
sel.ar_lags
res = sel.model.fit()
print(res.summary())
# Out:
#                             AutoReg Model Results
# ==============================================================================
# Dep. Variable:              AdrActCnt   No. Observations:                 1779
# Model:                     AutoReg(1)   Log Likelihood               -2697.131
# Method:               Conditional MLE   S.D. of innovations              1.103
# Date:                Wed, 23 Jun 2021   AIC                              0.199
# Time:                        08:10:36   BIC                              0.209
# Sample:                             1   HQIC                             0.203
#                                  1779
# ================================================================================
#                    coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const            0.0397      0.026      1.517      0.129      -0.012       0.091
# AdrActCnt.L1     0.1169      0.024      4.962      0.000       0.071       0.163
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            8.5568           +0.0000j            8.5568            0.0000
# -----------------------------------------------------------------------------
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/base/tsa_model.py:579: ValueWarning:
#
# An unsupported index was provided and will be ignored when e.g. forecasting.
#
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/base/tsa_model.py:579: ValueWarning:
#
# An unsupported index was provided and will be ignored when e.g. forecasting.

# %%
fig = plt.figure(figsize=(16,9))
fig = res.plot_diagnostics(fig=fig, lags=30)

# %%
s.shape
# Out:
# (1779,)

# %% [markdown]
# ploting predictions

# %%
fig = res.plot_predict()
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# ### allow global search to allow longer lag without requiring shorter lags.

# %%
s=df['AdrActCnt'].pct_change(1).dropna()
sel = ar_select_order(s, 13,'aic',glob=True, old_names=False)
sel.ar_lags
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/base/tsa_model.py:579: ValueWarning:
#
# An unsupported index was provided and will be ignored when e.g. forecasting.
#
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/base/tsa_model.py:579: ValueWarning:
#
# An unsupported index was provided and will be ignored when e.g. forecasting.
# array([1])

# %%
s=df['AdrActCnt'].pct_change(1).dropna()
sel = ar_select_order(s, 13, 'aic', glob=True, old_names=False)
sel.ar_lags
res = sel.model.fit()
print(res.summary())
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/base/tsa_model.py:579: ValueWarning:
#
# An unsupported index was provided and will be ignored when e.g. forecasting.
#                             AutoReg Model Results
# ==============================================================================
# Dep. Variable:              AdrActCnt   No. Observations:                 1779
# Model:                     AutoReg(1)   Log Likelihood               -2697.131
# Method:               Conditional MLE   S.D. of innovations              1.103
# Date:                Wed, 23 Jun 2021   AIC                              0.199
# Time:                        08:11:01   BIC                              0.209
# Sample:                             1   HQIC                             0.203
#                                  1779
# ================================================================================
#                    coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const            0.0397      0.026      1.517      0.129      -0.012       0.091
# AdrActCnt.L1     0.1169      0.024      4.962      0.000       0.071       0.163
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            8.5568           +0.0000j            8.5568            0.0000
# -----------------------------------------------------------------------------
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/base/tsa_model.py:579: ValueWarning:
#
# An unsupported index was provided and will be ignored when e.g. forecasting.

# %%
fig = plt.figure(figsize=(16,9))
fig = res.plot_diagnostics(fig=fig, lags=30)

# %% [markdown]
# ### comparing

# %%
res_ar1 = AutoReg(s, 1, old_names=False).fit()
res_ar3 = AutoReg(s, 3, old_names=False).fit()

predictions = pd.DataFrame({"AR(1)": res_ar1.predict(start=1776, end=1800),
                            "AR(3)": res_ar3.predict(start=1776, end=1800)})
_, ax = plt.subplots()
ax = predictions.plot(ax=ax)
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/base/tsa_model.py:579: ValueWarning:
#
# An unsupported index was provided and will be ignored when e.g. forecasting.
#
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/base/tsa_model.py:579: ValueWarning:
#
# An unsupported index was provided and will be ignored when e.g. forecasting.
#
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/base/tsa_model.py:379: ValueWarning:
#
# No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/base/tsa_model.py:379: ValueWarning:
#
# No supported index is available. Prediction results will be given with an integer index beginning at `start`.

# %% [markdown]
# ### The Dickey-Fuller test for stationary
#
# Null hypothesis:not stationary
#
#
# https://machinelearningmastery.com/time-series-data-stationary-python/

# %%
s=df['AdrActCnt'].pct_change(1).dropna()
from statsmodels.tsa.stattools import adfuller
result = adfuller(s)
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
print('Critical Values:')
for key, value in result[4].items():
	print('\t%s: %.3f' % (key, value))
# Out:
# ADF Statistic: -37.474363
# p-value: 0.000000
# Critical Values:
# 	1%: -3.434
# 	5%: -2.863
# 	10%: -2.568

# %%
s=df['AdrActCnt'].dropna()
from statsmodels.tsa.stattools import adfuller
result = adfuller(s)
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
print('Critical Values:')
for key, value in result[4].items():
	print('\t%s: %.3f' % (key, value))
# Out:
# ADF Statistic: -6.823897
# p-value: 0.000000
# Critical Values:
# 	1%: -3.434
# 	5%: -2.863
# 	10%: -2.568

# %% [markdown]
# # ARIMA Regression

# %% [markdown]
# https://www.statsmodels.org/stable/examples/notebooks/generated/tsa_arma_0.html
# https://machinelearningmastery.com/arima-for-time-series-forecasting-with-python/

# %%
import numpy as np
from scipy import stats
import pandas as pd
import matplotlib.pyplot as plt

import statsmodels.api as sm
from statsmodels.tsa.arima.model import ARIMA

# %%
from statsmodels.graphics.api import qqplot

# %%
s=df['AdrActCnt']
fig = plt.figure(figsize=(12,8))
ax1 = fig.add_subplot(211)
fig = sm.graphics.tsa.plot_acf(s, lags=40, ax=ax1)
ax2 = fig.add_subplot(212)
fig = sm.graphics.tsa.plot_pacf(s, lags=40, ax=ax2)
